# %% [markdown]
# <a href="https://colab.research.google.com/github/sumonaung-23/AIEng-Assignments/blob/main/notebooks/myanmar_emotion_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas scikit-learn transformers datasets sentencepiece

# %%
pip install torch

# %%
import pandas as pd

# Use the 'raw' URL from GitHub
url = "https://raw.githubusercontent.com/sumonaung-23/AIEng-Assignments/main/data/myanmar_emotions.csv"

# Read the CSV
df = pd.read_csv(url)

# Preview the data
print(df.head())
# Out:
#                             text emotion
# 0            ဒီနေ့ အရမ်းပျော်တယ်     joy
# 1       မင်းကိုတွေ့ရတာ ဝမ်းသာတယ်     joy
# 2   အောင်မြင်မှုရလို့ ပျော်နေတယ်     joy
# 3  ဒီသတင်းကြားရတာ အရမ်းဝမ်းသာတယ်     joy
# 4  သူတို့နဲ့တွေ့ပြီး ပျော်ခဲ့တယ်     joy

# %%
df = pd.read_csv(url, encoding='utf-8')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(df["text"])
y = df["emotion"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 0.5

# %%
sentence = ["အရမ်းဝမ်းနည်းပါတယ်"]

vec = vectorizer.transform(sentence)
prediction = model.predict(vec)

print("Emotion:", prediction[0])
# Out:
# Emotion: sadness
